# %%
import pandas
import numpy


# set appropriate options for pandas
pandas.set_option('display.max_rows', 20)

# %%
# load the dataset into the workspace
data = pandas.read_csv('./datasets/Chronic_Kidney_Disease/chronic_kidney_disease_full.csv')
data
# Out:
#     age   bp     sg al su       rbc        pc         pcc          ba  bgr  \
# 0    48   80  1.020  1  0         ?    normal  notpresent  notpresent  121
# 1     7   50  1.020  4  0         ?    normal  notpresent  notpresent    ?
# 2    62   80  1.010  2  3    normal    normal  notpresent  notpresent  423
# 3    48   70  1.005  4  0    normal  abnormal     present  notpresent  117
# 4    51   80  1.010  2  0    normal    normal  notpresent  notpresent  106
# 5    60   90  1.015  3  0         ?         ?  notpresent  notpresent   74
# 6    68   70  1.010  0  0         ?    normal  notpresent  notpresent  100
# 7    24    ?  1.015  2  4    normal  abnormal  notpresent  notpresent  410
# 8    52  100  1.015  3  0    normal  abnormal     present  notpresent  138
# 9    53   90  1.020  2  0  abnormal  abnormal     present  notpresent   70
# ..   ..  ...    ... .. ..       ...       ...         ...         ...  ...
# 387  52   80  1.025  0  0    normal    normal  notpresent  notpresent   99
# 388  36   80  1.025  0  0    normal    normal  notpresent  notpresent   85
# 389  57   80  1.020  0  0    normal    normal  notpresent  notpresent  133
# 390  43   60  1.025  0  0    normal    normal  notpresent  notpresent  117
# 391  50   80  1.020  0  0    normal    normal  notpresent  notpresent  137
# 392  55   80  1.020  0  0    normal    normal  notpresent  notpresent  140
# 393  42   70  1.025  0  0    normal    normal  notpresent  notpresent   75
# 394  12   80  1.020  0  0    normal    normal  notpresent  notpresent  100
# 395  17   60  1.025  0  0    normal    normal  notpresent  notpresent  114
# 396  58   80  1.025  0  0    normal    normal  notpresent  notpresent  131
#
#       ...   pcv   wbcc rbcc  htn   dm cad appet   pe  ane   class
# 0     ...    44   7800  5.2  yes  yes  no  good   no   no     ckd
# 1     ...    38   6000    ?   no   no  no  good   no   no     ckd
# 2     ...    31   7500    ?   no  yes  no  poor   no  yes     ckd
# 3     ...    32   6700  3.9  yes   no  no  poor  yes  yes     ckd
# 4     ...    35   7300  4.6   no   no  no  good   no   no     ckd
# 5     ...    39   7800  4.4  yes  yes  no  good  yes   no     ckd
# 6     ...    36      ?    ?   no   no  no  good   no   no     ckd
# 7     ...    44   6900    5   no  yes  no  good  yes   no     ckd
# 8     ...    33   9600  4.0  yes  yes  no  good   no  yes     ckd
# 9     ...    29  12100  3.7  yes  yes  no  poor   no  yes     ckd
# ..    ...    ..    ...  ...  ...  ...  ..   ...  ...  ...     ...
# 387   ...    52   6300  5.3   no   no  no  good   no   no  notckd
# 388   ...    44   5800  6.3   no   no  no  good   no   no  notckd
# 389   ...    46   6600  5.5   no   no  no  good   no   no  notckd
# 390   ...    54   7400  5.4   no   no  no  good   no   no  notckd
# 391   ...    45   9500  4.6   no   no  no  good   no   no  notckd
# 392   ...    47   6700  4.9   no   no  no  good   no   no  notckd
# 393   ...    54   7800  6.2   no   no  no  good   no   no  notckd
# 394   ...    49   6600  5.4   no   no  no  good   no   no  notckd
# 395   ...    51   7200  5.9   no   no  no  good   no   no  notckd
# 396   ...    53   6800  6.1   no   no  no  good   no   no  notckd
#
# [397 rows x 25 columns]

# %%
import warnings


# turning warnings off
warnings.catch_warnings()


from xgboost import XGBClassifier

# %%
data.dtypes
# Out:
# age      float64
# bp       float64
# sg       float64
# al       float64
# su       float64
# rbc      float64
# pc       float64
# pcc      float64
# ba       float64
# bgr      float64
#           ...
# pcv      float64
# wbcc     float64
# rbcc     float64
# htn      float64
# dm       float64
# cad      float64
# appet    float64
# pe       float64
# ane      float64
# class    float64
# Length: 25, dtype: object

# %%
# let's see what we have here?!
data.columns, len(data.columns)
# Out:
# (Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#         'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
#         'appet', 'pe', 'ane', 'class'],
#        dtype='object'), 25)

# %%
# select target and features
features = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'dm', 'cad',
        'appet', 'pe', 'ane']
target = ['class']

# %%
# separate X, from Y
X, Y = data[features], data[target]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y =\
train_test_split(X, Y, test_size=0.3, random_state=0)

# %%
# visit http://xgboost.readthedocs.io/en/latest/parameter.html for more info on hyper parameter tuning
#help(XGBClassifier)
pass

# %%
model = XGBClassifier(max_depth=3, learning_rate=0.1, n_estimators=100, silent=False, 
                      objective='binary:logistic', nthread=-1, gamma=0, min_child_weight=1, 
                      max_delta_step=0, subsample=1, colsample_bytree=1, colsample_bylevel=1, 
                      reg_alpha=0, reg_lambda=1, scale_pos_weight=1, base_score=0.5, seed=0, 
                      missing=None)

# train the model
model.fit(x_train, y_train, eval_metric='logloss', verbose=True)
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:95: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/user/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:128: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# XGBClassifier(base_score=0.5, colsample_bylevel=1, colsample_bytree=1,
#        gamma=0, learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='multi:softprob', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=False, subsample=1)

# %%
## I dont like nans
#data.replace('?', numpy.nan, inplace=True)
#data.dropna(inplace=True)

## or
# data = data[data != '?']

# replace the nan with mode
def fix_bad_values(x):
    try:
        x = float(x)
    except:
        return numpy.nan
    else: 
        return x
    
data.replace('?', numpy.nan, inplace=True)

def is_categorial(x):
    try:
        float(x)
    except:
        return True
    else: 
        return False

def encode(x):
    return hash(x)

for column in data.columns:
    mode = data[column].mode()[0]
    print(column, mode, type(mode))
    if is_categorial(mode):
        data[column].fillna(mode, inplace=True)
        data[column] = data[column].apply(encode)
    else:
        data[column] = data[column].apply(fix_bad_values)
        mean = data[column].astype(numpy.float).mean()
        data[column].fillna(mean, inplace=True)
data
# Out:
# age 60.0 <class 'numpy.float64'>
# bp 80.0 <class 'numpy.float64'>
# sg 1.02 <class 'numpy.float64'>
# al 0.0 <class 'numpy.float64'>
# su 0.0 <class 'numpy.float64'>
# rbc -5830071190897818612 <class 'numpy.int64'>
# pc -5830071190897818612 <class 'numpy.int64'>
# pcc -2559973900244556267 <class 'numpy.int64'>
# ba -2559973900244556267 <class 'numpy.int64'>
# bgr 147.86440678 <class 'numpy.float64'>
# bu 57.608994709 <class 'numpy.float64'>
# sc 1.2 <class 'numpy.float64'>
# sod 137.508012821 <class 'numpy.float64'>
# pot 4.6308681672 <class 'numpy.float64'>
# hemo 12.5208695652 <class 'numpy.float64'>
# pcv 38.8226299694 <class 'numpy.float64'>
# wbcc 8404.79452055 <class 'numpy.float64'>
# rbcc 4.70224719101 <class 'numpy.float64'>
# htn -1638290092332007705 <class 'numpy.int64'>
# dm -1638290092332007705 <class 'numpy.int64'>
# cad -1638290092332007705 <class 'numpy.int64'>
# appet -6594713608256469180 <class 'numpy.int64'>
# pe -1638290092332007705 <class 'numpy.int64'>
# ane -1638290092332007705 <class 'numpy.int64'>
# class -3052917346674969941 <class 'numpy.int64'>
#       age          bp     sg   al   su           rbc            pc  \
# 0    48.0   80.000000  1.020  1.0  0.0 -5.830071e+18 -5.830071e+18
# 1     7.0   50.000000  1.020  4.0  0.0 -5.830071e+18 -5.830071e+18
# 2    62.0   80.000000  1.010  2.0  3.0 -5.830071e+18 -5.830071e+18
# 3    48.0   70.000000  1.005  4.0  0.0 -5.830071e+18  2.511775e+18
# 4    51.0   80.000000  1.010  2.0  0.0 -5.830071e+18 -5.830071e+18
# 5    60.0   90.000000  1.015  3.0  0.0 -5.830071e+18 -5.830071e+18
# 6    68.0   70.000000  1.010  0.0  0.0 -5.830071e+18 -5.830071e+18
# 7    24.0   76.467532  1.015  2.0  4.0 -5.830071e+18  2.511775e+18
# 8    52.0  100.000000  1.015  3.0  0.0 -5.830071e+18  2.511775e+18
# 9    53.0   90.000000  1.020  2.0  0.0  2.511775e+18  2.511775e+18
# ..    ...         ...    ...  ...  ...           ...           ...
# 387  52.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 388  36.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 389  57.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 390  43.0   60.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 391  50.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 392  55.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 393  42.0   70.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 394  12.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 395  17.0   60.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 396  58.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
#
#               pcc            ba         bgr      ...        pcv          wbcc  \
# 0   -2.559974e+18 -2.559974e+18  121.000000      ...       44.0   7800.000000
# 1   -2.559974e+18 -2.559974e+18  147.864407      ...       38.0   6000.000000
# 2   -2.559974e+18 -2.559974e+18  423.000000      ...       31.0   7500.000000
# 3    1.541943e+18 -2.559974e+18  117.000000      ...       32.0   6700.000000
# 4   -2.559974e+18 -2.559974e+18  106.000000      ...       35.0   7300.000000
# 5   -2.559974e+18 -2.559974e+18   74.000000      ...       39.0   7800.000000
# 6   -2.559974e+18 -2.559974e+18  100.000000      ...       36.0   8404.794521
# 7   -2.559974e+18 -2.559974e+18  410.000000      ...       44.0   6900.000000
# 8    1.541943e+18 -2.559974e+18  138.000000      ...       33.0   9600.000000
# 9    1.541943e+18 -2.559974e+18   70.000000      ...       29.0  12100.000000
# ..            ...           ...         ...      ...        ...           ...
# 387 -2.559974e+18 -2.559974e+18   99.000000      ...       52.0   6300.000000
# 388 -2.559974e+18 -2.559974e+18   85.000000      ...       44.0   5800.000000
# 389 -2.559974e+18 -2.559974e+18  133.000000      ...       46.0   6600.000000
# 390 -2.559974e+18 -2.559974e+18  117.000000      ...       54.0   7400.000000
# 391 -2.559974e+18 -2.559974e+18  137.000000      ...       45.0   9500.000000
# 392 -2.559974e+18 -2.559974e+18  140.000000      ...       47.0   6700.000000
# 393 -2.559974e+18 -2.559974e+18   75.000000      ...       54.0   7800.000000
# 394 -2.559974e+18 -2.559974e+18  100.000000      ...       49.0   6600.000000
# 395 -2.559974e+18 -2.559974e+18  114.000000      ...       51.0   7200.000000
# 396 -2.559974e+18 -2.559974e+18  131.000000      ...       53.0   6800.000000
#
#          rbcc           htn            dm           cad         appet  \
# 0    5.200000 -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18
# 1    4.702247 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 2    4.702247 -1.638290e+18 -2.152968e+18 -1.638290e+18  8.248684e+18
# 3    3.900000 -2.152968e+18 -1.638290e+18 -1.638290e+18  8.248684e+18
# 4    4.600000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 5    4.400000 -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18
# 6    4.702247 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 7    5.000000 -1.638290e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18
# 8    4.000000 -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18
# 9    3.700000 -2.152968e+18 -2.152968e+18 -1.638290e+18  8.248684e+18
# ..        ...           ...           ...           ...           ...
# 387  5.300000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 388  6.300000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 389  5.500000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 390  5.400000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 391  4.600000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 392  4.900000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 393  6.200000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 394  5.400000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 395  5.900000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
# 396  6.100000 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18
#
#                pe           ane         class
# 0   -1.638290e+18 -1.638290e+18 -3.052917e+18
# 1   -1.638290e+18 -1.638290e+18 -3.052917e+18
# 2   -1.638290e+18 -2.152968e+18 -3.052917e+18
# 3   -2.152968e+18 -2.152968e+18 -3.052917e+18
# 4   -1.638290e+18 -1.638290e+18 -3.052917e+18
# 5   -2.152968e+18 -1.638290e+18 -3.052917e+18
# 6   -1.638290e+18 -1.638290e+18 -3.052917e+18
# 7   -2.152968e+18 -1.638290e+18 -3.052917e+18
# 8   -1.638290e+18 -2.152968e+18 -3.052917e+18
# 9   -1.638290e+18 -2.152968e+18 -3.052917e+18
# ..            ...           ...           ...
# 387 -1.638290e+18 -1.638290e+18  6.072122e+18
# 388 -1.638290e+18 -1.638290e+18  6.072122e+18
# 389 -1.638290e+18 -1.638290e+18  6.072122e+18
# 390 -1.638290e+18 -1.638290e+18  6.072122e+18
# 391 -1.638290e+18 -1.638290e+18  6.072122e+18
# 392 -1.638290e+18 -1.638290e+18  6.072122e+18
# 393 -1.638290e+18 -1.638290e+18  6.072122e+18
# 394 -1.638290e+18 -1.638290e+18  6.072122e+18
# 395 -1.638290e+18 -1.638290e+18  6.072122e+18
# 396 -1.638290e+18 -1.638290e+18  6.072122e+18
#
# [397 rows x 25 columns]

# %%
# make the predictions
y_hat = model.predict(x_test)

# %%
make_df = pandas.DataFrame
y_and_y_hat = pandas.concat([y.rename(columns={"class": "y"}).reset_index(), 
                             make_df({"y_hat": list(y_hat)})], axis="columns")
y_and_y_hat
# Out:
#      index             y         y_hat
# 0       65 -3.052917e+18 -3.052917e+18
# 1      132 -3.052917e+18 -3.052917e+18
# 2       74 -3.052917e+18 -3.052917e+18
# 3       78 -3.052917e+18 -3.052917e+18
# 4       37 -3.399185e+18 -3.052917e+18
# 5       54 -3.052917e+18 -3.052917e+18
# 6      293  6.072122e+18  6.072122e+18
# 7       60 -3.052917e+18 -3.052917e+18
# 8       12 -3.052917e+18 -3.052917e+18
# 9      361  6.072122e+18  6.072122e+18
# ..     ...           ...           ...
# 110     21 -3.052917e+18 -3.052917e+18
# 111    186 -3.052917e+18 -3.052917e+18
# 112    231 -3.052917e+18 -3.052917e+18
# 113    362  6.072122e+18  6.072122e+18
# 114     49 -3.052917e+18 -3.052917e+18
# 115    235 -3.052917e+18 -3.052917e+18
# 116    298  6.072122e+18  6.072122e+18
# 117     92 -3.052917e+18 -3.052917e+18
# 118    220 -3.052917e+18 -3.052917e+18
# 119    225 -3.052917e+18 -3.052917e+18
#
# [120 rows x 3 columns]

# %%
from sklearn.metrics import classification_report, accuracy_score

# %%
error_function = accuracy_score
report = error_function(y_and_y_hat["y"], y_and_y_hat["y_hat"])
print(report)
# Out:
# 0.991666666667

# %%
data['rnd1'] = numpy.random.randint(0, 100 , size=(data.shape[0], 1))

# %%
# select target and features
features = ['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wbcc', 'rbcc', 'htn', 'cad', 'dm',
        'appet', 'pe', 'ane', 'rnd1']
target = ['class']

# %%
data
# Out:
#       age          bp     sg   al   su           rbc            pc  \
# 0    48.0   80.000000  1.020  1.0  0.0 -5.830071e+18 -5.830071e+18
# 1     7.0   50.000000  1.020  4.0  0.0 -5.830071e+18 -5.830071e+18
# 2    62.0   80.000000  1.010  2.0  3.0 -5.830071e+18 -5.830071e+18
# 3    48.0   70.000000  1.005  4.0  0.0 -5.830071e+18  2.511775e+18
# 4    51.0   80.000000  1.010  2.0  0.0 -5.830071e+18 -5.830071e+18
# 5    60.0   90.000000  1.015  3.0  0.0 -5.830071e+18 -5.830071e+18
# 6    68.0   70.000000  1.010  0.0  0.0 -5.830071e+18 -5.830071e+18
# 7    24.0   76.467532  1.015  2.0  4.0 -5.830071e+18  2.511775e+18
# 8    52.0  100.000000  1.015  3.0  0.0 -5.830071e+18  2.511775e+18
# 9    53.0   90.000000  1.020  2.0  0.0  2.511775e+18  2.511775e+18
# ..    ...         ...    ...  ...  ...           ...           ...
# 387  52.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 388  36.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 389  57.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 390  43.0   60.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 391  50.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 392  55.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 393  42.0   70.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 394  12.0   80.000000  1.020  0.0  0.0 -5.830071e+18 -5.830071e+18
# 395  17.0   60.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
# 396  58.0   80.000000  1.025  0.0  0.0 -5.830071e+18 -5.830071e+18
#
#               pcc            ba         bgr  ...           wbcc      rbcc  \
# 0   -2.559974e+18 -2.559974e+18  121.000000  ...    7800.000000  5.200000
# 1   -2.559974e+18 -2.559974e+18  147.864407  ...    6000.000000  4.702247
# 2   -2.559974e+18 -2.559974e+18  423.000000  ...    7500.000000  4.702247
# 3    1.541943e+18 -2.559974e+18  117.000000  ...    6700.000000  3.900000
# 4   -2.559974e+18 -2.559974e+18  106.000000  ...    7300.000000  4.600000
# 5   -2.559974e+18 -2.559974e+18   74.000000  ...    7800.000000  4.400000
# 6   -2.559974e+18 -2.559974e+18  100.000000  ...    8404.794521  4.702247
# 7   -2.559974e+18 -2.559974e+18  410.000000  ...    6900.000000  5.000000
# 8    1.541943e+18 -2.559974e+18  138.000000  ...    9600.000000  4.000000
# 9    1.541943e+18 -2.559974e+18   70.000000  ...   12100.000000  3.700000
# ..            ...           ...         ...  ...            ...       ...
# 387 -2.559974e+18 -2.559974e+18   99.000000  ...    6300.000000  5.300000
# 388 -2.559974e+18 -2.559974e+18   85.000000  ...    5800.000000  6.300000
# 389 -2.559974e+18 -2.559974e+18  133.000000  ...    6600.000000  5.500000
# 390 -2.559974e+18 -2.559974e+18  117.000000  ...    7400.000000  5.400000
# 391 -2.559974e+18 -2.559974e+18  137.000000  ...    9500.000000  4.600000
# 392 -2.559974e+18 -2.559974e+18  140.000000  ...    6700.000000  4.900000
# 393 -2.559974e+18 -2.559974e+18   75.000000  ...    7800.000000  6.200000
# 394 -2.559974e+18 -2.559974e+18  100.000000  ...    6600.000000  5.400000
# 395 -2.559974e+18 -2.559974e+18  114.000000  ...    7200.000000  5.900000
# 396 -2.559974e+18 -2.559974e+18  131.000000  ...    6800.000000  6.100000
#
#               htn            dm           cad         appet            pe  \
# 0   -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 1   -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 2   -1.638290e+18 -2.152968e+18 -1.638290e+18  8.248684e+18 -1.638290e+18
# 3   -2.152968e+18 -1.638290e+18 -1.638290e+18  8.248684e+18 -2.152968e+18
# 4   -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 5   -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18 -2.152968e+18
# 6   -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 7   -1.638290e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18 -2.152968e+18
# 8   -2.152968e+18 -2.152968e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 9   -2.152968e+18 -2.152968e+18 -1.638290e+18  8.248684e+18 -1.638290e+18
# ..            ...           ...           ...           ...           ...
# 387 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 388 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 389 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 390 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 391 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 392 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 393 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 394 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 395 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
# 396 -1.638290e+18 -1.638290e+18 -1.638290e+18 -6.594714e+18 -1.638290e+18
#
#               ane         class  rnd1
# 0   -1.638290e+18 -3.052917e+18    50
# 1   -1.638290e+18 -3.052917e+18    90
# 2   -2.152968e+18 -3.052917e+18    60
# 3   -2.152968e+18 -3.052917e+18    75
# 4   -1.638290e+18 -3.052917e+18    66
# 5   -1.638290e+18 -3.052917e+18    64
# 6   -1.638290e+18 -3.052917e+18    81
# 7   -1.638290e+18 -3.052917e+18    96
# 8   -2.152968e+18 -3.052917e+18     1
# 9   -2.152968e+18 -3.052917e+18    98
# ..            ...           ...   ...
# 387 -1.638290e+18  6.072122e+18    31
# 388 -1.638290e+18  6.072122e+18     9
# 389 -1.638290e+18  6.072122e+18    73
# 390 -1.638290e+18  6.072122e+18    64
# 391 -1.638290e+18  6.072122e+18    38
# 392 -1.638290e+18  6.072122e+18    17
# 393 -1.638290e+18  6.072122e+18    14
# 394 -1.638290e+18  6.072122e+18    23
# 395 -1.638290e+18  6.072122e+18    39
# 396 -1.638290e+18  6.072122e+18    32
#
# [397 rows x 26 columns]

# %%
hash("good")%2
# Out:
# 0

# %%
hash('present')%2, hash('notpresent')%2
# Out:
# (1, 1)
